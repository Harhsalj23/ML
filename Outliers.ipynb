# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = sns.get_dataset_names()
print(data)
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
daf = sns.load_dataset('tips')
daf.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(x="total_bill",data=daf)
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.histplot(x="total_bill",data=daf)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = sns.get_dataset_names()
daf = sns.load_dataset('tips')
sns.histplot(x="tip", data=daf)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.kdeplot(data=daf,x='tip',y="total_bill")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
daf.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
from scipy.stats import zscore

# %%
q1 = daf["tip"].quantile(0.25)
q3 = daf["tip"].quantile(0.75)
iqr = q3-q1
posout = q3+1.5*iqr
negout = q1-1.5*iqr
for i in daf["tip"]:
    if i>posout or i <negout:
        print(i)
# Out:
# 7.58
# 6.0
# 6.73
# 6.7
# 10.0
# 6.5
# 9.0
# 6.5
# 5.92
